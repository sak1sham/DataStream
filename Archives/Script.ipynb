# %%
from pymongo import MongoClient
import os
from dotenv import load_dotenv
import certifi

load_dotenv()
mongopwd = os.getenv('MONGOPWD')
mongourl = 'mongodb+srv://saksham:{}@supportservice.3md7h.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'.format(mongopwd)
client = MongoClient(mongourl, tlsCAFile=certifi.where())
db = client['support-service']

# %%
import pandas as pd
import time
import json
import datetime

def convert_list_to_string(l):
    val = "["
    for item in l:
        if(isinstance(item, list) or isinstance(item, set) or isinstance(item, tuple)):
            item = convert_list_to_string(list(item))
        elif(isinstance(item, bool) or isinstance(item, float) or isinstance(item, complex) or isinstance(item, int)):
            item = str(item)
        elif(isinstance(item, dict)):
            item = json.dumps(item)
        elif(isinstance(item, datetime.datetime)):
            item = item.strftime("%m/%d/%Y, %H:%M:%S")
        val = val + item
    val = val + ']'
    return val

def dataframe_from_collection(current_collection_name):
    docu = []
    count = 0
    total_len = current_collection_name.count_documents({})
    print("Found", total_len, "documents.")
    for document in current_collection_name.find():
        for key, value in document.items():
            if(key == '_id'):
                document[key] = str(document[key])
            elif(isinstance(document[key], int) or isinstance(document[key], float) or isinstance(document[key], complex)):
                document[key] = str(document[key])
            elif(isinstance(document[key], list)):
                document[key] = convert_list_to_string(document[key])
            elif(isinstance(document[key], bool)):
                document[key] = str(document[key])
        count += 1
        docu.append(document)
        if(count % 10000 == 0):
            print(count, "Documents fetched.................", int(count*100/total_len), "%")
            
    return pd.DataFrame(docu)

def fetch_and_convert_data(database_, fetch_type = "selected", collection_name = []):

    if(fetch_type == 'all'):
        collection_name = database_.list_collection_names()
        
    for curr_collection in collection_name:
        t1 = time.time()
        print("Processing", curr_collection)
        df_collection = dataframe_from_collection(database_[curr_collection])
        print("Converted to Pandas Dataframe. Now, saving to parquet format")
        file_name = "./converted/" + curr_collection + '.parquet'
        try:
            df_collection.to_parquet(file_name)
            print("Saved", file_name)
            t2 = time.time()
            print("Time Taken:", t2-t1, "seconds", end="\n\n")
        except:
            return df_collection

    print('Done!')

# %%
result_df = fetch_and_convert_data(db, fetch_type="all")
# Out:
# Processing support_list
# Found 21 documents.
# Converted to Pandas Dataframe. Now, saving to parquet format
# Saved ./converted/support_list.parquet
# Time Taken: 2.6323611736297607 seconds
#
# Processing webhook_error_logs
# Found 0 documents.
# Converted to Pandas Dataframe. Now, saving to parquet format
# Saved ./converted/webhook_error_logs.parquet
# Time Taken: 0.08346080780029297 seconds
#
# Processing support_tickets
# Found 680042 documents.
# 10000 Documents fetched................. 1 %
# 20000 Documents fetched................. 2 %
# 30000 Documents fetched................. 4 %
# 40000 Documents fetched................. 5 %
# 50000 Documents fetched................. 7 %
# 60000 Documents fetched................. 8 %
# 70000 Documents fetched................. 10 %
# 80000 Documents fetched................. 11 %
# 90000 Documents fetched................. 13 %
# 100000 Documents fetched................. 14 %
# 110000 Documents fetched................. 16 %
# 120000 Documents fetched................. 17 %
# 130000 Documents fetched................. 19 %
# 140000 Documents fetched................. 20 %
# 150000 Documents fetched................. 22 %
# 160000 Documents fetched................. 23 %
# 170000 Documents fetched................. 24 %
# 180000 Documents fetched................. 26 %
# 190000 Documents fetched................. 27 %
# 200000 Documents fetched................. 29 %
# 210000 Documents fetched................. 30 %
# 220000 Documents fetched................. 32 %
# 230000 Documents fetched................. 33 %
# 240000 Documents fetched................. 35 %
# 250000 Documents fetched................. 36 %
# 260000 Documents fetched................. 38 %
# 270000 Documents fetched................. 39 %
# 280000 Documents fetched................. 41 %
# 290000 Documents fetched................. 42 %
# 300000 Documents fetched................. 44 %
# 310000 Documents fetched................. 45 %
# 320000 Documents fetched................. 47 %
# 330000 Documents fetched................. 48 %
# 340000 Documents fetched................. 49 %
# 350000 Documents fetched................. 51 %
# 360000 Documents fetched................. 52 %
# 370000 Documents fetched................. 54 %
# 380000 Documents fetched................. 55 %
# 390000 Documents fetched................. 57 %
# 400000 Documents fetched................. 58 %
# 410000 Documents fetched................. 60 %
# 420000 Documents fetched................. 61 %
# 430000 Documents fetched................. 63 %
# 440000 Documents fetched................. 64 %
# 450000 Documents fetched................. 66 %
# 460000 Documents fetched................. 67 %
# 470000 Documents fetched................. 69 %
# 480000 Documents fetched................. 70 %
# 490000 Documents fetched................. 72 %
# 500000 Documents fetched................. 73 %
# 510000 Documents fetched................. 74 %
# 520000 Documents fetched................. 76 %
# 530000 Documents fetched................. 77 %
# 540000 Documents fetched................. 79 %
# 550000 Documents fetched................. 80 %
# 560000 Documents fetched................. 82 %
# 570000 Documents fetched................. 83 %
# 580000 Documents fetched................. 85 %
# 590000 Documents fetched................. 86 %
# 600000 Documents fetched................. 88 %
# 610000 Documents fetched................. 89 %
# 620000 Documents fetched................. 91 %
# 630000 Documents fetched................. 92 %
# 640000 Documents fetched................. 94 %
# 650000 Documents fetched................. 95 %
# 660000 Documents fetched................. 97 %
# 670000 Documents fetched................. 98 %
# 680000 Documents fetched................. 99 %
# /var/folders/py/_v4_f34n0ld8myg0n6w7rwcc0000gn/T/ipykernel_18709/1673258290.py:41: FutureWarning: Inferring datetime64[ns, pytz.FixedOffset(330)] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns, pytz.FixedOffset(330)])
#   return pd.DataFrame(docu)
# Converted to Pandas Dataframe. Now, saving to parquet format
# Saved ./converted/support_tickets.parquet
# Time Taken: 1384.187625169754 seconds
#
# Processing support_tickets_rating
# Found 21091 documents.
# 10000 Documents fetched................. 47 %
# 20000 Documents fetched................. 94 %
# Converted to Pandas Dataframe. Now, saving to parquet format
# Saved ./converted/support_tickets_rating.parquet
# Time Taken: 24.923013925552368 seconds
#
# Processing leader_kyc
# Found 0 documents.
# Converted to Pandas Dataframe. Now, saving to parquet format
# Saved ./converted/leader_kyc.parquet
# Time Taken: 0.09340429306030273 seconds
#
# Processing support_form_items
# Found 6 documents.
# Converted to Pandas Dataframe. Now, saving to parquet format
# Saved ./converted/support_form_items.parquet
# Time Taken: 0.08456206321716309 seconds
#
# Processing support_items
# Found 94 documents.
# Converted to Pandas Dataframe. Now, saving to parquet format
# Saved ./converted/support_items.parquet
# Time Taken: 0.18226265907287598 seconds
#
# Processing support_ticket_conversations
# Found 1784618 documents.
# 10000 Documents fetched................. 0 %
# 20000 Documents fetched................. 1 %
# 30000 Documents fetched................. 1 %
# 40000 Documents fetched................. 2 %
# 50000 Documents fetched................. 2 %
# 60000 Documents fetched................. 3 %
# 70000 Documents fetched................. 3 %
# 80000 Documents fetched................. 4 %
# 90000 Documents fetched................. 5 %
# 100000 Documents fetched................. 5 %
# 110000 Documents fetched................. 6 %
# 120000 Documents fetched................. 6 %
# 130000 Documents fetched................. 7 %
# 140000 Documents fetched................. 7 %
# 150000 Documents fetched................. 8 %
# 160000 Documents fetched................. 8 %
# 170000 Documents fetched................. 9 %
# 180000 Documents fetched................. 10 %
# 190000 Documents fetched................. 10 %
# 200000 Documents fetched................. 11 %
# 210000 Documents fetched................. 11 %
# 220000 Documents fetched................. 12 %
# 230000 Documents fetched................. 12 %
# 240000 Documents fetched................. 13 %
# 250000 Documents fetched................. 14 %
# 260000 Documents fetched................. 14 %
# 270000 Documents fetched................. 15 %
# 280000 Documents fetched................. 15 %
# 290000 Documents fetched................. 16 %
# 300000 Documents fetched................. 16 %
# 310000 Documents fetched................. 17 %
# 320000 Documents fetched................. 17 %
# 330000 Documents fetched................. 18 %
# 340000 Documents fetched................. 19 %
# 350000 Documents fetched................. 19 %
# 360000 Documents fetched................. 20 %
# 370000 Documents fetched................. 20 %
# 380000 Documents fetched................. 21 %
# 390000 Documents fetched................. 21 %
# 400000 Documents fetched................. 22 %
# 410000 Documents fetched................. 22 %
# 420000 Documents fetched................. 23 %
# 430000 Documents fetched................. 24 %
# 440000 Documents fetched................. 24 %
# 450000 Documents fetched................. 25 %
# 460000 Documents fetched................. 25 %
# 470000 Documents fetched................. 26 %
# 480000 Documents fetched................. 26 %
# 490000 Documents fetched................. 27 %
# 500000 Documents fetched................. 28 %
# 510000 Documents fetched................. 28 %
# 520000 Documents fetched................. 29 %
# 530000 Documents fetched................. 29 %
# 540000 Documents fetched................. 30 %
# 550000 Documents fetched................. 30 %
# 560000 Documents fetched................. 31 %
# 570000 Documents fetched................. 31 %
# 580000 Documents fetched................. 32 %
# 590000 Documents fetched................. 33 %
# 600000 Documents fetched................. 33 %
# 610000 Documents fetched................. 34 %
# 620000 Documents fetched................. 34 %
# 630000 Documents fetched................. 35 %
# 640000 Documents fetched................. 35 %
# 650000 Documents fetched................. 36 %
# 660000 Documents fetched................. 36 %
# 670000 Documents fetched................. 37 %
# 680000 Documents fetched................. 38 %
# 690000 Documents fetched................. 38 %
# 700000 Documents fetched................. 39 %
# 710000 Documents fetched................. 39 %
# 720000 Documents fetched................. 40 %
# 730000 Documents fetched................. 40 %
# 740000 Documents fetched................. 41 %
# 750000 Documents fetched................. 42 %
# 760000 Documents fetched................. 42 %
# 770000 Documents fetched................. 43 %
# 780000 Documents fetched................. 43 %
# 790000 Documents fetched................. 44 %
# 800000 Documents fetched................. 44 %
# 810000 Documents fetched................. 45 %
# 820000 Documents fetched................. 45 %
# 830000 Documents fetched................. 46 %
# 840000 Documents fetched................. 47 %
# 850000 Documents fetched................. 47 %
# 860000 Documents fetched................. 48 %
# 870000 Documents fetched................. 48 %
# 880000 Documents fetched................. 49 %
# 890000 Documents fetched................. 49 %
# 900000 Documents fetched................. 50 %
# 910000 Documents fetched................. 50 %
# 920000 Documents fetched................. 51 %
# 930000 Documents fetched................. 52 %
# 940000 Documents fetched................. 52 %
# 950000 Documents fetched................. 53 %
# 960000 Documents fetched................. 53 %
# 970000 Documents fetched................. 54 %
# 980000 Documents fetched................. 54 %
# 990000 Documents fetched................. 55 %
# 1000000 Documents fetched................. 56 %
# 1010000 Documents fetched................. 56 %
# 1020000 Documents fetched................. 57 %
# 1030000 Documents fetched................. 57 %
# 1040000 Documents fetched................. 58 %
# 1050000 Documents fetched................. 58 %
# 1060000 Documents fetched................. 59 %
# 1070000 Documents fetched................. 59 %
# 1080000 Documents fetched................. 60 %
# 1090000 Documents fetched................. 61 %
# 1100000 Documents fetched................. 61 %
# 1110000 Documents fetched................. 62 %
# 1120000 Documents fetched................. 62 %
# 1130000 Documents fetched................. 63 %
# 1140000 Documents fetched................. 63 %
# 1150000 Documents fetched................. 64 %
# 1160000 Documents fetched................. 64 %
# 1170000 Documents fetched................. 65 %
# 1180000 Documents fetched................. 66 %
# 1190000 Documents fetched................. 66 %
# 1200000 Documents fetched................. 67 %
# 1210000 Documents fetched................. 67 %
# 1220000 Documents fetched................. 68 %
# 1230000 Documents fetched................. 68 %
# 1240000 Documents fetched................. 69 %
# 1250000 Documents fetched................. 70 %
# 1260000 Documents fetched................. 70 %
# 1270000 Documents fetched................. 71 %
# 1280000 Documents fetched................. 71 %
# 1290000 Documents fetched................. 72 %
# 1300000 Documents fetched................. 72 %
# 1310000 Documents fetched................. 73 %
# 1320000 Documents fetched................. 73 %
# 1330000 Documents fetched................. 74 %
# 1340000 Documents fetched................. 75 %
# 1350000 Documents fetched................. 75 %
# 1360000 Documents fetched................. 76 %
# 1370000 Documents fetched................. 76 %
# 1380000 Documents fetched................. 77 %
# 1390000 Documents fetched................. 77 %
# 1400000 Documents fetched................. 78 %
# 1410000 Documents fetched................. 79 %
# 1420000 Documents fetched................. 79 %
# 1430000 Documents fetched................. 80 %
# 1440000 Documents fetched................. 80 %
# 1450000 Documents fetched................. 81 %
# 1460000 Documents fetched................. 81 %
# 1470000 Documents fetched................. 82 %
# 1480000 Documents fetched................. 82 %
# 1490000 Documents fetched................. 83 %
# 1500000 Documents fetched................. 84 %
# 1510000 Documents fetched................. 84 %
# 1520000 Documents fetched................. 85 %
# 1530000 Documents fetched................. 85 %
# 1540000 Documents fetched................. 86 %
# 1550000 Documents fetched................. 86 %
# 1560000 Documents fetched................. 87 %
# 1570000 Documents fetched................. 87 %
# 1580000 Documents fetched................. 88 %
# 1590000 Documents fetched................. 89 %
# 1600000 Documents fetched................. 89 %
# 1610000 Documents fetched................. 90 %
# 1620000 Documents fetched................. 90 %
# 1630000 Documents fetched................. 91 %
# 1640000 Documents fetched................. 91 %
# 1650000 Documents fetched................. 92 %
# 1660000 Documents fetched................. 93 %
# 1670000 Documents fetched................. 93 %
# 1680000 Documents fetched................. 94 %
# 1690000 Documents fetched................. 94 %
# 1700000 Documents fetched................. 95 %
# 1710000 Documents fetched................. 95 %
# 1720000 Documents fetched................. 96 %
# 1730000 Documents fetched................. 96 %
# 1740000 Documents fetched................. 97 %
# 1750000 Documents fetched................. 98 %
# 1760000 Documents fetched................. 98 %
# 1770000 Documents fetched................. 99 %
# 1780000 Documents fetched................. 99 %
# Converted to Pandas Dataframe. Now, saving to parquet format
# Saved ./converted/support_ticket_conversations.parquet
# Time Taken: 1456.7880907058716 seconds
#
# Done!
